# %% [markdown]
# ## Vamos analisar os dados do seu spotify usando a API!

# %% [markdown]
# https://developer.spotify.com/dashboard/

# %% [markdown]
# Criar um App na sua conta

# %% [markdown]
# analysis > Web app > Não comercial > aceitar todas as condições

# %% [markdown]
# **Pegar cliente ID e cliente SECRET**

# %% [markdown]
# Usaremos a biblioteca **spotipy**:
#
# https://spotipy.readthedocs.io/en/latest/

# %%
! pip install spotipy

# %% [markdown]
# https://spotipy.readthedocs.io/en/latest/

# %% [markdown]
# Aqui abaixo você precisa mudar com os valores do seu spotify!

# %%
username='iancaleite'
client_secret='fd19a0cededf4424a215bd47d0769ada'
client_id='9fc56f5f95a94544b3140483a2fee4be'

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ## Vamos autenticar nosso app!
#
# Autenticando apenas o app, não o usuário, só temos acesso aos dados públicos.

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Todas as playlists criadas pelo spotify

# %%
playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 spotify:playlist:37i9dQZF1DXcBWIGoYBM5M Today's Top Hits
#    2 spotify:playlist:37i9dQZF1DX0XUsuxWHRQd RapCaviar
#    3 spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n mint
#    4 spotify:playlist:37i9dQZF1DX4SBhb3fqCJd Are & Be
#    5 spotify:playlist:37i9dQZF1DXcF6B6QPhFDv Rock This
#    6 spotify:playlist:37i9dQZF1DX1lVhptIYRda Hot Country
#    7 spotify:playlist:37i9dQZF1DX10zKzsJ2jva ¡Viva Latino!
#    8 spotify:playlist:37i9dQZF1DX4JAvHpjipBk New Music Friday
#    9 spotify:playlist:37i9dQZF1DX4E3UdUs7fUx Afternoon Acoustic
#   10 spotify:playlist:37i9dQZF1DX4sWSpwq3LiO Peaceful Piano
#   11 spotify:playlist:37i9dQZF1DWYV7OOaGhoH0 Roots Rising
#   12 spotify:playlist:5JdIoXkjfuyWmDdDnznmq1 Lost In Austin: Country Music from SXSW
#   13 spotify:playlist:37i9dQZF1DX5PuwKY2VZBZ SXSW: HipHopUpNext
#   14 spotify:playlist:37i9dQZF1DWXJfnUiYjUKT New Music Friday
#   15 spotify:playlist:4HghCZXykAY0kdRqJipQJd Music Inspired By Mogul
# ...

# %% [markdown]
# Informações sobre o meu usuário

# %%
ianca = sp.user('iancaleite')

# %%
print(ianca)
# Out:
# {'display_name': 'Ianca Leite', 'external_urls': {'spotify': 'https://open.spotify.com/user/iancaleite'}, 'followers': {'href': None, 'total': 3}, 'href': 'https://api.spotify.com/v1/users/iancaleite', 'id': 'iancaleite', 'images': [{'height': None, 'url': 'https://platform-lookaside.fbsbx.com/platform/profilepic/?asid=1627403420908686&height=200&width=200&ext=1558879380&hash=AeQzuNuWMiiT-OIZ', 'width': None}], 'type': 'user', 'uri': 'spotify:user:iancaleite'}

# %% [markdown]
# Agora, informações sobre o seu usuário

# %%
user = sp.user(username)

# %%
print(user)
# Out:
# {'display_name': 'Ianca Leite', 'external_urls': {'spotify': 'https://open.spotify.com/user/iancaleite'}, 'followers': {'href': None, 'total': 3}, 'href': 'https://api.spotify.com/v1/users/iancaleite', 'id': 'iancaleite', 'images': [{'height': None, 'url': 'https://platform-lookaside.fbsbx.com/platform/profilepic/?asid=1627403420908686&height=200&width=200&ext=1558879380&hash=AeQzuNuWMiiT-OIZ', 'width': None}], 'type': 'user', 'uri': 'spotify:user:iancaleite'}

# %% [markdown]
# Suas playlists públicas

# %%
my_playlists = sp.user_playlists(username)
for playlist in my_playlists['items']:
    print(playlist['name'])
# Out:
# todo de Sofía Reyes
# Chiclete (As Mais Ouvidas 2019)
# This Is MC Kevinho
# Funk At Home
# Having Fun
# Hip hop to dance

# %% [markdown]
# ## Agora autenticar nosso usuário para usar o app

# %%
import os

# %%
os.environ["SPOTIPY_CLIENT_ID"] = "9fc56f5f95a94544b3140483a2fee4be"
os.environ["SPOTIPY_CLIENT_SECRET"] = "fd19a0cededf4424a215bd47d0769ada"
os.environ["SPOTIPY_REDIRECT_URI"] = "https://localhost:8080"

# %% [markdown]
# O escopo vai dizer o que queremos ler desse usuário. Está tudo na documentação. https://developer.spotify.com/documentation/general/guides/scopes/

# %%
scope='user-read-recently-played user-follow-read'

# %% [markdown]
# Precisamos de um token que vai dizer ao aplicativo que o usuário autoriza. <br>
# Uma nova janela/aba será criada, copie o link que consta nessa janela/aba.

# %%
token = util.prompt_for_user_token(username, scope)

# %%
print(token)
# Out:
# BQAiPRRf1w5PJLMlaaKCpZO4Xds32nhBf6_EiVJycMUL3txErN767A2rXHa4uiv8K5AuKXXbgozjFEHshrT_3c8StXssC_ilf5gos-abnUkAinpwAFlVSiY5K2AVjeOXIeELk3uB8Xw9a8ADtxMkRgg-PopeeEhBtoMCJbyrlsEU

# %%
import pprint

# %% [markdown]
# **Analisando 20 dos artistas que você segue**

# %%
if token:
    sp = spotipy.Spotify(auth=token)
    sp.trace = False
    results = sp.current_user_followed_artists(limit=30)
    pprint.pprint(results)
else:
    print("Can't get token for", username)
# Out:
# {'artists': {'cursors': {'after': '6syQjkQSMIrzw5cFnNRheo'},
#              'href': 'https://api.spotify.com/v1/me/following?type=artist&limit=30',
#              'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0GWNKI3VPEcJsOIEhUjmxd'},
#                         'followers': {'href': None, 'total': 571165},
#                         'genres': ['brazilian hip hop', 'brazilian reggae'],
#                         'href': 'https://api.spotify.com/v1/artists/0GWNKI3VPEcJsOIEhUjmxd',
#                         'id': '0GWNKI3VPEcJsOIEhUjmxd',
#                         'images': [{'height': 640,
#                                     'url': 'https://i.scdn.co/image/e8e16785e45f09bede3153c70a926c5d6f3d44d5',
#                                     'width': 640},
#                                    {'height': 320,
#                                     'url': 'https://i.scdn.co/image/fa91c0effa11dc3de30af242dda4e8f46d41031c',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(results['artists']['items'])

# %%
df
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/0...
# 1   {'spotify': 'https://open.spotify.com/artist/0...
# 2   {'spotify': 'https://open.spotify.com/artist/0...
# 3   {'spotify': 'https://open.spotify.com/artist/0...
# 4   {'spotify': 'https://open.spotify.com/artist/0...
# 5   {'spotify': 'https://open.spotify.com/artist/0...
# 6   {'spotify': 'https://open.spotify.com/artist/1...
# 7   {'spotify': 'https://open.spotify.com/artist/1...
# 8   {'spotify': 'https://open.spotify.com/artist/1...
# 9   {'spotify': 'https://open.spotify.com/artist/1...
# 10  {'spotify': 'https://open.spotify.com/artist/1...
# 11  {'spotify': 'https://open.spotify.com/artist/1...
# 12  {'spotify': 'https://open.spotify.com/artist/1...
# 13  {'spotify': 'https://open.spotify.com/artist/2...
# 14  {'spotify': 'https://open.spotify.com/artist/2...
# 15  {'spotify': 'https://open.spotify.com/artist/2...
# ...

# %%
df['name']
# Out:
# 0                         Rael
# 1                      Oriente
# 2                 Fabio Brazza
# 3                  Cynthia Luz
# 4                    DJ Khaled
# 5                  Sofia Reyes
# 6                      Mahalia
# 7                     Gramatik
# 8                       Maneva
# 9                        509-E
# 10                 Choro Das 3
# 11                  MC Kevinho
# 12                    J Balvin
# 13                      Big Up
# 14       MC Neguinho do Kaxeta
# 15              Racionais MC's
# 16    Bob Marley & The Wailers
# 17                  Rebelution
# 18                   blackbear
# 19                    Edi Rock
# 20                        SOJA
# 21                Alessia Cara
# 22                       Drake
# 23             Priscila Tossan
# 24                    Rita Ora
# 25                   DJ Shadow
# 26            Sérgio Dall'orto
# 27                  Jhene Aiko
# 28                 Tee Krispil
# 29            Rincon Sapiência
# ...

# %%
df['genres']
# Out:
# 0                 [brazilian hip hop, brazilian reggae]
# 1            [brazilian electronica, brazilian hip hop]
# 2                                   [brazilian hip hop]
# 3     [brazilian electronica, brazilian hip hop, r&b...
# 4     [dance pop, hip hop, miami hip hop, pop, pop r...
# 5       [dance pop, latin, latin pop, mexican pop, pop]
# 6     [alternative r&b, indie anthem-folk, indie r&b...
# 7     [chillhop, downtempo, jazz boom bap, nu jazz, ...
# 8     [brazilian electronica, brazilian hip hop, bra...
# 9                  [brazilian hip hop, funk ostentacao]
# 10                       [brazilian composition, choro]
# 11                      [funk carioca, funk ostentacao]
# 12                              [latin, pop, reggaeton]
# 13                                   [brazilian reggae]
# 14          [brega funk, funk carioca, funk ostentacao]
# 15                 [brazilian hip hop, funk ostentacao]
# 16                               [reggae, roots reggae]
# ...

# %%
for list in df['genres']:
    print(list)
# Out:
# ['brazilian hip hop', 'brazilian reggae']
# ['brazilian electronica', 'brazilian hip hop']
# ['brazilian hip hop']
# ['brazilian electronica', 'brazilian hip hop', 'r&b brasileiro', 'trap brasileiro']
# ['dance pop', 'hip hop', 'miami hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap music']
# ['dance pop', 'latin', 'latin pop', 'mexican pop', 'pop']
# ['alternative r&b', 'indie anthem-folk', 'indie r&b', 'uk contemporary r&b']
# ['chillhop', 'downtempo', 'jazz boom bap', 'nu jazz', 'slovenian electronic', 'trip hop']
# ['brazilian electronica', 'brazilian hip hop', 'brazilian reggae', 'pop nacional']
# ['brazilian hip hop', 'funk ostentacao']
# ['brazilian composition', 'choro']
# ['funk carioca', 'funk ostentacao']
# ['latin', 'pop', 'reggaeton']
# ['brazilian reggae']
# ['brega funk', 'funk carioca', 'funk ostentacao']
# ['brazilian hip hop', 'funk ostentacao']
# ['reggae', 'roots reggae']
# ['reggae rock']
# ['pop']
# ['brazilian hip hop', 'funk ostentacao']
# ...

# %%
all_genres = []
for list in df['genres']:
    for genre in list:
        all_genres.append(genre)

print(all_genres)
# Out:
# ['brazilian hip hop', 'brazilian reggae', 'brazilian electronica', 'brazilian hip hop', 'brazilian hip hop', 'brazilian electronica', 'brazilian hip hop', 'r&b brasileiro', 'trap brasileiro', 'dance pop', 'hip hop', 'miami hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap music', 'dance pop', 'latin', 'latin pop', 'mexican pop', 'pop', 'alternative r&b', 'indie anthem-folk', 'indie r&b', 'uk contemporary r&b', 'chillhop', 'downtempo', 'jazz boom bap', 'nu jazz', 'slovenian electronic', 'trip hop', 'brazilian electronica', 'brazilian hip hop', 'brazilian reggae', 'pop nacional', 'brazilian hip hop', 'funk ostentacao', 'brazilian composition', 'choro', 'funk carioca', 'funk ostentacao', 'latin', 'pop', 'reggaeton', 'brazilian reggae', 'brega funk', 'funk carioca', 'funk ostentacao', 'brazilian hip hop', 'funk ostentacao', 'reggae', 'roots reggae', 'reggae rock', 'pop', 'brazilian hip hop', 'funk ostentacao', 'jawaiian', 'reggae', 'reggae rock', 'canadian contemporary 
# ...

# %%
all_genres.sort()

# %%
all_genres
# Out:
# ['alternative r&b',
#  'alternative r&b',
#  'baile pop',
#  'big beat',
#  'brazilian composition',
#  'brazilian electronica',
#  'brazilian electronica',
#  'brazilian electronica',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian hip hop',
#  'brazilian reggae',
#  'brazilian reggae',
#  'brazilian reggae',
#  'brega funk',
#  'canadian contemporary r&b',
#  'canadian hip hop',
#  'canadian pop',
#  'chillhop',
#  'choro',
#  'dance pop',
#  'dance pop',
#  'dance pop',
#  'dance pop',
#  'dance pop',
#  'downtempo',
#  'downtempo',
#  'electronic',
#  'funk carioca',
#  'funk carioca',
#  'funk ostentacao',
#  'funk ostentacao',
#  'funk ostentacao',
#  'funk ostentacao',
#  'funk ostentacao',
#  'hip hop',
#  'hip hop',
#  'hip hop',
#  'hip pop',
#  'indie anthem-folk',
#  'indie r&b',
#  'jawaiian',
#  'jazz boom bap',
# ...

# %%
from collections import Counter

# %%
count_genres = Counter(all_genres)

# %%
print(count_genres)
# Out:
# Counter({'brazilian hip hop': 9, 'pop': 7, 'dance pop': 5, 'funk ostentacao': 5, 'r&b': 4, 'brazilian electronica': 3, 'brazilian reggae': 3, 'hip hop': 3, 'pop rap': 3, 'rap': 3, 'alternative r&b': 2, 'downtempo': 2, 'funk carioca': 2, 'latin': 2, 'nu jazz': 2, 'post-teen pop': 2, 'reggae': 2, 'reggae rock': 2, 'trap brasileiro': 2, 'trip hop': 2, 'baile pop': 1, 'big beat': 1, 'brazilian composition': 1, 'brega funk': 1, 'canadian contemporary r&b': 1, 'canadian hip hop': 1, 'canadian pop': 1, 'chillhop': 1, 'choro': 1, 'electronic': 1, 'hip pop': 1, 'indie anthem-folk': 1, 'indie r&b': 1, 'jawaiian': 1, 'jazz boom bap': 1, 'latin pop': 1, 'mexican pop': 1, 'miami hip hop': 1, 'pop nacional': 1, 'r&b brasileiro': 1, 'reggaeton': 1, 'roots reggae': 1, 'slovenian electronic': 1, 'southern hip hop': 1, 'trap music': 1, 'tropical house': 1, 'turntablism': 1, 'uk contemporary r&b': 1, 'uk pop': 1, 'urban contemporary': 1})

# %%
type(count_genres)
# Out:
# collections.Counter

# %%
import matplotlib.pyplot as plt

# %%
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# Distribuição dos gêneros musicais para esses artistas

# %%
plt.bar(count_genres.keys(), count_genres.values())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Agora vamos analisar as músicas salvas

# %%
saved = sp.current_user_saved_tracks()
while saved['next']:
  saved = sp.next(saved)

# %%
pprint.pprint(saved)
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=140&limit=20',
#  'items': [{'added_at': '2018-04-28T06:00:12Z',
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2QsynagSdAqZj3U9HgDzjD'},
#                                              'href': 'https://api.spotify.com/v1/artists/2QsynagSdAqZj3U9HgDzjD',
#                                              'id': '2QsynagSdAqZj3U9HgDzjD',
#                                              'name': 'Bob Marley & The Wailers',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2QsynagSdAqZj3U9HgDzjD'}],
#                                 'available_markets': [],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3q8y9MBuOdOzwJb8QJfwBG'},
# ...

# %%
s_items = saved['items']

# %%
df_s = pd.DataFrame.from_dict(saved['items'])

# %%
df_s
# Out:
#                 added_at                                              track
# 0   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 1   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 2   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 3   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 4   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 5   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 6   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 7   2018-04-28T06:00:12Z  {'album': {'album_type': 'album', 'artists': [...
# 8   2018-04-22T20:45:15Z  {'album': {'album_type': 'single', 'artists': ...
# 9   2018-04-19T03:59:58Z  {'album': {'album_type': 'album', 'artists': [...
# 10  2018-04-17T23:09:28Z  {'album': {'album_type': 'single', 'artists': ...
# ...
